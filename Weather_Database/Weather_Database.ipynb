# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3a2e7710a8ed> in <module>
#       2 import requests
#       3 # Import the API key.
# ----> 4 from config import weather_api_key
#       5 # Import the datetime module from the datetime library.
#       6 from datetime import datetime
#
# ModuleNotFoundError: No module named 'config'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #print(city.title())
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        #print(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in our list.
record_count = 1
set_count = 1
city_data = []
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
#     print(city_url)
#     print("---------------")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_disc = city_weather["weather"][0]["description"] 
        city_country = city_weather["sys"]["country"] 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country, 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_disc})
                          #"Date": city_date})
        
         
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saint anthony
# Processing Record 2 of Set 1 | ilhabela
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | whitianga
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | primorsko-akhtarsk
# Processing Record 10 of Set 1 | nioro
# Processing Record 11 of Set 1 | evensk
# Processing Record 12 of Set 1 | nam phong
# Processing Record 13 of Set 1 | bubaque
# Processing Record 14 of Set 1 | elko
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | tautira
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | blagoveshchensk
# Processing Record 24 of Set 1 | vostok
# Processing Record 25 of Set 1 | arauca
# Processing Record 26 of Set 1 | matucana
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | codrington
# Processing Record 33 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | fortuna
# Processing Record 36 of Set 1 | alihe
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | matagami
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | leningradskiy
# Processing Record 42 of Set 1 | palmas bellas
# Processing Record 43 of Set 1 | katsuura
# Processing Record 44 of Set 1 | paratinga
# Processing Record 45 of Set 1 | arosa
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | beruwala
# Processing Record 1 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 2 | kholodnyy
# Processing Record 3 of Set 2 | gouyave
# Processing Record 4 of Set 2 | poum
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | drnovice
# Processing Record 7 of Set 2 | butterworth
# Processing Record 8 of Set 2 | saint-pierre
# Processing Record 9 of Set 2 | college
# Processing Record 10 of Set 2 | tanout
# Processing Record 11 of Set 2 | castries
# Processing Record 12 of Set 2 | roald
# Processing Record 13 of Set 2 | san luis
# Processing Record 14 of Set 2 | chernyshevskiy
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | dakar
# Processing Record 17 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 18 of Set 2 | cartagena
# Processing Record 19 of Set 2 | rudnogorsk
# Processing Record 20 of Set 2 | batagay-alyta
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | vilyuysk
# Processing Record 23 of Set 2 | najran
# Processing Record 24 of Set 2 | salisbury
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | ushuaia
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | valparaiso
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | ola
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | klaksvik
# Processing Record 41 of Set 2 | emerald
# Processing Record 42 of Set 2 | cervo
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | khasan
# Processing Record 45 of Set 2 | korem
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | sisian
# Processing Record 48 of Set 2 | kushiro
# Processing Record 49 of Set 2 | bonavista
# Processing Record 50 of Set 2 | vila velha
# Processing Record 1 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | hammerfest
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | margate
# Processing Record 6 of Set 3 | bystryy istok
# Processing Record 7 of Set 3 | simao
# Processing Record 8 of Set 3 | kamaishi
# Processing Record 9 of Set 3 | prado
# Processing Record 10 of Set 3 | aklavik
# Processing Record 11 of Set 3 | gushikawa
# Processing Record 12 of Set 3 | kahului
# Processing Record 13 of Set 3 | nayoro
# Processing Record 14 of Set 3 | solnechnyy
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | mackay
# Processing Record 17 of Set 3 | kavieng
# Processing Record 18 of Set 3 | mujiayingzi
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | nampula
# Processing Record 21 of Set 3 | nelson bay
# Processing Record 22 of Set 3 | san patricio
# Processing Record 23 of Set 3 | severo-kurilsk
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | iqaluit
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 3 | gravelbourg
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | rincon
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | husavik
# Processing Record 35 of Set 3 | paranapanema
# Processing Record 36 of Set 3 | khani
# Processing Record 37 of Set 3 | bathsheba
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | emba
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | cusuna
# Processing Record 42 of Set 3 | maracas
# Processing Record 43 of Set 3 | karpathos
# Processing Record 44 of Set 3 | kaseda
# Processing Record 45 of Set 3 | acapulco
# Processing Record 46 of Set 3 | lagoa
# Processing Record 47 of Set 3 | san cristobal
# Processing Record 48 of Set 3 | hilo
# Processing Record 49 of Set 3 | dawlatabad
# Processing Record 50 of Set 3 | port hardy
# Processing Record 1 of Set 4 | zhuanghe
# Processing Record 2 of Set 4 | yamada
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | meulaboh
# Processing Record 5 of Set 4 | souillac
# Processing Record 6 of Set 4 | atar
# Processing Record 7 of Set 4 | chicama
# Processing Record 8 of Set 4 | banepa
# Processing Record 9 of Set 4 | kaeo
# Processing Record 10 of Set 4 | voi
# Processing Record 11 of Set 4 | troitskoye
# Processing Record 12 of Set 4 | kruisfontein
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | padang
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 4 | matara
# Processing Record 19 of Set 4 | longyearbyen
# Processing Record 20 of Set 4 | quatre cocos
# Processing Record 21 of Set 4 | birjand
# Processing Record 22 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | bandarbeyla
# Processing Record 24 of Set 4 | lata
# Processing Record 25 of Set 4 | waddan
# Processing Record 26 of Set 4 | rundu
# Processing Record 27 of Set 4 | pecos
# Processing Record 28 of Set 4 | chingirlau
# Processing Record 29 of Set 4 | port blair
# Processing Record 30 of Set 4 | bologoye
# Processing Record 31 of Set 4 | aitape
# Processing Record 32 of Set 4 | avarua
# Processing Record 33 of Set 4 | saint-augustin
# Processing Record 34 of Set 4 | aykhal
# Processing Record 35 of Set 4 | alyangula
# Processing Record 36 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 4 | saskylakh
# Processing Record 38 of Set 4 | kandrian
# Processing Record 39 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 4 | warri
# Processing Record 41 of Set 4 | vyselki
# Processing Record 42 of Set 4 | oranjemund
# Processing Record 43 of Set 4 | erzin
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | muisne
# Processing Record 46 of Set 4 | vestmannaeyjar
# Processing Record 47 of Set 4 | nanortalik
# Processing Record 48 of Set 4 | roma
# Processing Record 49 of Set 4 | celestun
# Processing Record 50 of Set 4 | komsomolskiy
# Processing Record 1 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 5 | cockburn town
# Processing Record 3 of Set 5 | xinqing
# Processing Record 4 of Set 5 | phan thiet
# Processing Record 5 of Set 5 | sistranda
# Processing Record 6 of Set 5 | manggar
# Processing Record 7 of Set 5 | champerico
# Processing Record 8 of Set 5 | new port richey
# Processing Record 9 of Set 5 | nortelandia
# Processing Record 10 of Set 5 | camacha
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | dongsheng
# Processing Record 13 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 5 | sao paulo de olivenca
# Processing Record 15 of Set 5 | castro
# Processing Record 16 of Set 5 | murray bridge
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | marabba
# Processing Record 19 of Set 5 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 20 of Set 5 | srednekolymsk
# Processing Record 21 of Set 5 | tezu
# Processing Record 22 of Set 5 | soto la marina
# Processing Record 23 of Set 5 | kapaa
# Processing Record 24 of Set 5 | colombo
# Processing Record 25 of Set 5 | saldanha
# Processing Record 26 of Set 5 | hithadhoo
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | severodvinsk
# Processing Record 29 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 5 | tres picos
# Processing Record 31 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 5 | mehamn
# Processing Record 33 of Set 5 | kharp
# Processing Record 34 of Set 5 | poya
# Processing Record 35 of Set 5 | pechora
# Processing Record 36 of Set 5 | partsa
# Processing Record 37 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 38 of Set 5 | ribeira grande
# Processing Record 39 of Set 5 | chokurdakh
# Processing Record 40 of Set 5 | tarimoro
# Processing Record 41 of Set 5 | pevek
# Processing Record 42 of Set 5 | hamilton
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | yulara
# Processing Record 46 of Set 5 | westport
# Processing Record 47 of Set 5 | caucaia
# Processing Record 48 of Set 5 | katobu
# Processing Record 49 of Set 5 | goure
# Processing Record 50 of Set 5 | huilong
# Processing Record 1 of Set 6 | florence
# Processing Record 2 of Set 6 | igarape-miri
# City not found. Skipping...
# Processing Record 3 of Set 6 | hofn
# Processing Record 4 of Set 6 | puerto del rosario
# Processing Record 5 of Set 6 | seoul
# Processing Record 6 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 6 | limoges
# Processing Record 8 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 6 | tual
# Processing Record 10 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 6 | cranbrook
# Processing Record 12 of Set 6 | itoman
# Processing Record 13 of Set 6 | muroto
# Processing Record 14 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 6 | pasighat
# Processing Record 16 of Set 6 | laguna
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | orgun
# City not found. Skipping...
# Processing Record 19 of Set 6 | sao felix do xingu
# Processing Record 20 of Set 6 | dafeng
# Processing Record 21 of Set 6 | tigil
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | sanming
# Processing Record 24 of Set 6 | shelburne
# Processing Record 25 of Set 6 | olafsvik
# Processing Record 26 of Set 6 | peterhead
# Processing Record 27 of Set 6 | paamiut
# Processing Record 28 of Set 6 | coihaique
# Processing Record 29 of Set 6 | havre-saint-pierre
# Processing Record 30 of Set 6 | baracoa
# Processing Record 31 of Set 6 | samarai
# Processing Record 32 of Set 6 | lavrentiya
# Processing Record 33 of Set 6 | arenys de mar
# Processing Record 34 of Set 6 | saint pete beach
# Processing Record 35 of Set 6 | sinnamary
# Processing Record 36 of Set 6 | vardo
# Processing Record 37 of Set 6 | palatka
# Processing Record 38 of Set 6 | mount isa
# Processing Record 39 of Set 6 | pangody
# Processing Record 40 of Set 6 | beloha
# Processing Record 41 of Set 6 | korla
# Processing Record 42 of Set 6 | bilovec
# Processing Record 43 of Set 6 | verkhoyansk
# Processing Record 44 of Set 6 | koslan
# Processing Record 45 of Set 6 | mount pleasant
# Processing Record 46 of Set 6 | weligama
# Processing Record 47 of Set 6 | kargil
# Processing Record 48 of Set 6 | henties bay
# Processing Record 49 of Set 6 | shelui
# Processing Record 50 of Set 6 | port-de-paix
# City not found. Skipping...
# Processing Record 1 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 2 of Set 7 | yar-sale
# Processing Record 3 of Set 7 | udachnyy
# Processing Record 4 of Set 7 | west bay
# Processing Record 5 of Set 7 | antalaha
# Processing Record 6 of Set 7 | ormara
# Processing Record 7 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 7 | gigmoto
# Processing Record 9 of Set 7 | baoqing
# Processing Record 10 of Set 7 | ileza
# Processing Record 11 of Set 7 | dharchula
# Processing Record 12 of Set 7 | rudsar
# Processing Record 13 of Set 7 | marsh harbour
# Processing Record 14 of Set 7 | zorritos
# Processing Record 15 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 16 of Set 7 | koumac
# Processing Record 17 of Set 7 | benemerito de las americas
# Processing Record 18 of Set 7 | governador valadares
# Processing Record 19 of Set 7 | coihueco
# Processing Record 20 of Set 7 | borogontsy
# Processing Record 21 of Set 7 | quang ngai
# Processing Record 22 of Set 7 | richards bay
# Processing Record 23 of Set 7 | wanning
# Processing Record 24 of Set 7 | cairns
# Processing Record 25 of Set 7 | puro
# Processing Record 26 of Set 7 | nantai
# Processing Record 27 of Set 7 | batemans bay
# Processing Record 28 of Set 7 | sisimiut
# Processing Record 29 of Set 7 | oyama
# Processing Record 30 of Set 7 | poso
# Processing Record 31 of Set 7 | mlalo
# Processing Record 32 of Set 7 | bukama
# Processing Record 33 of Set 7 | brae
# Processing Record 34 of Set 7 | caravelas
# Processing Record 35 of Set 7 | san diego
# Processing Record 36 of Set 7 | lac du bonnet
# Processing Record 37 of Set 7 | rafai
# Processing Record 38 of Set 7 | muborak
# Processing Record 39 of Set 7 | beeville
# Processing Record 40 of Set 7 | tura
# Processing Record 41 of Set 7 | farah
# Processing Record 42 of Set 7 | portland
# Processing Record 43 of Set 7 | plettenberg bay
# Processing Record 44 of Set 7 | rocky mountain house
# Processing Record 45 of Set 7 | verkhnyaya inta
# Processing Record 46 of Set 7 | belaya gora
# Processing Record 47 of Set 7 | banovce
# City not found. Skipping...
# Processing Record 48 of Set 7 | sri aman
# Processing Record 49 of Set 7 | torphins
# Processing Record 50 of Set 7 | umea
# Processing Record 1 of Set 8 | oktyabrskiy
# Processing Record 2 of Set 8 | bobcaygeon
# Processing Record 3 of Set 8 | durusu
# Processing Record 4 of Set 8 | conakry
# Processing Record 5 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 8 | crowthorne
# Processing Record 7 of Set 8 | phrai bung
# City not found. Skipping...
# Processing Record 8 of Set 8 | antigonish
# Processing Record 9 of Set 8 | rokytne
# Processing Record 10 of Set 8 | nanakuli
# Processing Record 11 of Set 8 | praia
# Processing Record 12 of Set 8 | aswan
# Processing Record 13 of Set 8 | the valley
# Processing Record 14 of Set 8 | sitka
# Processing Record 15 of Set 8 | xinzhi
# Processing Record 16 of Set 8 | qaanaaq
# Processing Record 17 of Set 8 | dori
# Processing Record 18 of Set 8 | yerbogachen
# Processing Record 19 of Set 8 | praia da vitoria
# Processing Record 20 of Set 8 | atikokan
# Processing Record 21 of Set 8 | ballina
# Processing Record 22 of Set 8 | mandan
# Processing Record 23 of Set 8 | imeni poliny osipenko
# Processing Record 24 of Set 8 | haines junction
# Processing Record 25 of Set 8 | manbij
# Processing Record 26 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 8 | egvekinot
# Processing Record 28 of Set 8 | rawson
# Processing Record 29 of Set 8 | dalvik
# Processing Record 30 of Set 8 | leh
# Processing Record 31 of Set 8 | maragogi
# Processing Record 32 of Set 8 | linxia
# Processing Record 33 of Set 8 | moissala
# Processing Record 34 of Set 8 | luanda
# Processing Record 35 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 36 of Set 8 | pisco
# Processing Record 37 of Set 8 | hearst
# Processing Record 38 of Set 8 | broken hill
# Processing Record 39 of Set 8 | singkang
# Processing Record 40 of Set 8 | orje
# Processing Record 41 of Set 8 | esna
# Processing Record 42 of Set 8 | warrington
# Processing Record 43 of Set 8 | bandundu
# Processing Record 44 of Set 8 | boueni
# Processing Record 45 of Set 8 | namibe
# Processing Record 46 of Set 8 | adrar
# Processing Record 47 of Set 8 | manitouwadge
# Processing Record 48 of Set 8 | buin
# Processing Record 49 of Set 8 | nishihara
# Processing Record 50 of Set 8 | darnah
# Processing Record 1 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 9 | shimoda
# Processing Record 3 of Set 9 | jimo
# Processing Record 4 of Set 9 | athabasca
# Processing Record 5 of Set 9 | chulucanas
# Processing Record 6 of Set 9 | thompson
# Processing Record 7 of Set 9 | lusambo
# Processing Record 8 of Set 9 | kuala lipis
# Processing Record 9 of Set 9 | hualmay
# Processing Record 10 of Set 9 | nantucket
# Processing Record 11 of Set 9 | makakilo city
# Processing Record 12 of Set 9 | broome
# Processing Record 13 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 9 | san ignacio
# Processing Record 15 of Set 9 | mabamba
# Processing Record 16 of Set 9 | calvia
# Processing Record 17 of Set 9 | glenwood springs
# Processing Record 18 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 9 | matli
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | san quintin
# Processing Record 22 of Set 9 | flinders
# Processing Record 23 of Set 9 | chuy
# Processing Record 24 of Set 9 | necochea
# Processing Record 25 of Set 9 | taverny
# Processing Record 26 of Set 9 | nirmal
# Processing Record 27 of Set 9 | yarensk
# Processing Record 28 of Set 9 | zheleznodorozhnyy
# Processing Record 29 of Set 9 | dingle
# Processing Record 30 of Set 9 | kvitok
# Processing Record 31 of Set 9 | anshun
# Processing Record 32 of Set 9 | nova olimpia
# Processing Record 33 of Set 9 | berlevag
# Processing Record 34 of Set 9 | bernalillo
# Processing Record 35 of Set 9 | morondava
# Processing Record 36 of Set 9 | bafra
# Processing Record 37 of Set 9 | ancud
# Processing Record 38 of Set 9 | skjervoy
# Processing Record 39 of Set 9 | araouane
# Processing Record 40 of Set 9 | okhotsk
# Processing Record 41 of Set 9 | whitehorse
# Processing Record 42 of Set 9 | hambantota
# Processing Record 43 of Set 9 | yelizovo
# Processing Record 44 of Set 9 | klenovyy
# Processing Record 45 of Set 9 | gazanjyk
# Processing Record 46 of Set 9 | las vegas
# Processing Record 47 of Set 9 | humboldt
# Processing Record 48 of Set 9 | concepcion
# Processing Record 49 of Set 9 | la seyne-sur-mer
# Processing Record 50 of Set 9 | oreanda
# City not found. Skipping...
# Processing Record 1 of Set 10 | kyshtovka
# Processing Record 2 of Set 10 | tiksi
# Processing Record 3 of Set 10 | trogir
# Processing Record 4 of Set 10 | tuy hoa
# Processing Record 5 of Set 10 | pontianak
# Processing Record 6 of Set 10 | fort nelson
# Processing Record 7 of Set 10 | denpasar
# Processing Record 8 of Set 10 | cangucu
# Processing Record 9 of Set 10 | swift current
# Processing Record 10 of Set 10 | ketchikan
# Processing Record 11 of Set 10 | yorkton
# Processing Record 12 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 10 | eidsvag
# Processing Record 14 of Set 10 | namatanai
# Processing Record 15 of Set 10 | touros
# Processing Record 16 of Set 10 | keflavik
# Processing Record 17 of Set 10 | garner
# Processing Record 18 of Set 10 | morgan city
# Processing Record 19 of Set 10 | ilulissat
# Processing Record 20 of Set 10 | mayumba
# Processing Record 21 of Set 10 | aviles
# Processing Record 22 of Set 10 | hobyo
# Processing Record 23 of Set 10 | krasnovishersk
# Processing Record 24 of Set 10 | rajmahal
# Processing Record 25 of Set 10 | naze
# Processing Record 26 of Set 10 | culfa
# Processing Record 27 of Set 10 | qaqortoq
# Processing Record 28 of Set 10 | kununurra
# Processing Record 29 of Set 10 | klooga
# Processing Record 30 of Set 10 | moose factory
# Processing Record 31 of Set 10 | szazhalombatta
# Processing Record 32 of Set 10 | bose
# Processing Record 33 of Set 10 | hasaki
# Processing Record 34 of Set 10 | phnum penh
# City not found. Skipping...
# Processing Record 35 of Set 10 | grushevskaya
# Processing Record 36 of Set 10 | cuite
# Processing Record 37 of Set 10 | coaldale
# Processing Record 38 of Set 10 | ossora
# Processing Record 39 of Set 10 | calatayud
# Processing Record 40 of Set 10 | kalanguy
# Processing Record 41 of Set 10 | kresttsy
# Processing Record 42 of Set 10 | garowe
# Processing Record 43 of Set 10 | chapais
# Processing Record 44 of Set 10 | grand gaube
# Processing Record 45 of Set 10 | dunda
# Processing Record 46 of Set 10 | ahipara
# Processing Record 47 of Set 10 | morro bay
# Processing Record 48 of Set 10 | hengyang
# Processing Record 49 of Set 10 | novopokrovka
# Processing Record 50 of Set 10 | kumla
# Processing Record 1 of Set 11 | mezen
# Processing Record 2 of Set 11 | bayan
# Processing Record 3 of Set 11 | de aar
# Processing Record 4 of Set 11 | falavarjan
# Processing Record 5 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 11 | kloulklubed
# Processing Record 7 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 11 | almunecar
# Processing Record 9 of Set 11 | kashi
# Processing Record 10 of Set 11 | taoudenni
# Processing Record 11 of Set 11 | pedreiras
# Processing Record 12 of Set 11 | rodrigues alves
# Processing Record 13 of Set 11 | kalevala
# Processing Record 14 of Set 11 | talnakh
# Processing Record 15 of Set 11 | tarakan
# Processing Record 16 of Set 11 | cedar city
# Processing Record 17 of Set 11 | barra velha
# Processing Record 18 of Set 11 | sola
# Processing Record 19 of Set 11 | brainerd
# Processing Record 20 of Set 11 | mizdah
# Processing Record 21 of Set 11 | vanimo
# Processing Record 22 of Set 11 | kedrovyy
# Processing Record 23 of Set 11 | harper
# Processing Record 24 of Set 11 | sept-iles
# Processing Record 25 of Set 11 | taksimo
# Processing Record 26 of Set 11 | camana
# Processing Record 27 of Set 11 | palafrugell
# Processing Record 28 of Set 11 | kitob
# Processing Record 29 of Set 11 | tancuayalab
# City not found. Skipping...
# Processing Record 30 of Set 11 | honningsvag
# Processing Record 31 of Set 11 | pochutla
# Processing Record 32 of Set 11 | kenai
# Processing Record 33 of Set 11 | svecha
# Processing Record 34 of Set 11 | taltal
# Processing Record 35 of Set 11 | verkhnyaya sinyachikha
# Processing Record 36 of Set 11 | brigantine
# Processing Record 37 of Set 11 | coquimbo
# Processing Record 38 of Set 11 | zhezkazgan
# Processing Record 39 of Set 11 | topchikha
# Processing Record 40 of Set 11 | jacqueville
# Processing Record 41 of Set 11 | sokolo
# Processing Record 42 of Set 11 | catamarca
# Processing Record 43 of Set 11 | faya
# Processing Record 44 of Set 11 | ilheus
# Processing Record 45 of Set 11 | at-bashi
# Processing Record 46 of Set 11 | iwaki
# Processing Record 47 of Set 11 | wenling
# Processing Record 48 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 50 of Set 11 | yuzhne
# Processing Record 1 of Set 12 | lugovoy
# Processing Record 2 of Set 12 | abancay
# Processing Record 3 of Set 12 | yeppoon
# Processing Record 4 of Set 12 | horsham
# Processing Record 5 of Set 12 | aksarka
# Processing Record 6 of Set 12 | kazerun
# Processing Record 7 of Set 12 | ahuimanu
# Processing Record 8 of Set 12 | riviere-au-renard
# Processing Record 9 of Set 12 | russell
# Processing Record 10 of Set 12 | haileybury
# Processing Record 11 of Set 12 | shahr-e babak
# Processing Record 12 of Set 12 | port lincoln
# Processing Record 13 of Set 12 | ozark
# Processing Record 14 of Set 12 | ohara
# Processing Record 15 of Set 12 | sambava
# Processing Record 16 of Set 12 | adelaide
# Processing Record 17 of Set 12 | waterloo
# Processing Record 18 of Set 12 | pimentel
# Processing Record 19 of Set 12 | kalmunai
# Processing Record 20 of Set 12 | burla
# Processing Record 21 of Set 12 | porbandar
# Processing Record 22 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 12 | since
# Processing Record 24 of Set 12 | podor
# Processing Record 25 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 12 | grindavik
# Processing Record 27 of Set 12 | port augusta
# Processing Record 28 of Set 12 | bella union
# Processing Record 29 of Set 12 | faro
# Processing Record 30 of Set 12 | jiuquan
# Processing Record 31 of Set 12 | chufarovo
# Processing Record 32 of Set 12 | peniche
# Processing Record 33 of Set 12 | salalah
# Processing Record 34 of Set 12 | road town
# Processing Record 35 of Set 12 | beringovskiy
# Processing Record 36 of Set 12 | okakarara
# Processing Record 37 of Set 12 | otjimbingwe
# Processing Record 38 of Set 12 | rafaela
# Processing Record 39 of Set 12 | nemuro
# Processing Record 40 of Set 12 | san juan
# Processing Record 41 of Set 12 | lorengau
# Processing Record 42 of Set 12 | okha
# Processing Record 43 of Set 12 | vao
# Processing Record 44 of Set 12 | umm lajj
# Processing Record 45 of Set 12 | zafra
# Processing Record 46 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 47 of Set 12 | rocha
# Processing Record 48 of Set 12 | kanniyakumari
# Processing Record 49 of Set 12 | poian
# Processing Record 50 of Set 12 | kutum
# Processing Record 1 of Set 13 | devonport
# Processing Record 2 of Set 13 | sangar
# Processing Record 3 of Set 13 | maceio
# Processing Record 4 of Set 13 | shirokiy
# Processing Record 5 of Set 13 | tuatapere
# Processing Record 6 of Set 13 | texarkana
# Processing Record 7 of Set 13 | iskateley
# Processing Record 8 of Set 13 | ahmadpur east
# Processing Record 9 of Set 13 | inirida
# Processing Record 10 of Set 13 | muros
# Processing Record 11 of Set 13 | turayf
# Processing Record 12 of Set 13 | natchitoches
# Processing Record 13 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 13 | anadyr
# Processing Record 15 of Set 13 | palmer
# Processing Record 16 of Set 13 | ponta delgada
# Processing Record 17 of Set 13 | sabla
# Processing Record 18 of Set 13 | kalmar
# Processing Record 19 of Set 13 | shinjo
# Processing Record 20 of Set 13 | iaciara
# Processing Record 21 of Set 13 | rio gallegos
# Processing Record 22 of Set 13 | fremont
# Processing Record 23 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 13 | paka
# Processing Record 25 of Set 13 | mazulskiy
# City not found. Skipping...
# Processing Record 26 of Set 13 | praya
# Processing Record 27 of Set 13 | inndyr
# Processing Record 28 of Set 13 | doha
# Processing Record 29 of Set 13 | churapcha
# Processing Record 30 of Set 13 | bocaiuva
# Processing Record 31 of Set 13 | wasilla
# Processing Record 32 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 13 | bundaberg
# Processing Record 34 of Set 13 | newcastle
# Processing Record 35 of Set 13 | kamenka
# Processing Record 36 of Set 13 | cancun
# Processing Record 37 of Set 13 | cardonal
# Processing Record 38 of Set 13 | harboore
# Processing Record 39 of Set 13 | terrace
# Processing Record 40 of Set 13 | prince rupert
# Processing Record 41 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 42 of Set 13 | laredo
# Processing Record 43 of Set 13 | boralday
# Processing Record 44 of Set 13 | san joaquin
# Processing Record 45 of Set 13 | lake cowichan
# Processing Record 46 of Set 13 | saint-francois
# Processing Record 47 of Set 13 | cuajinicuilapa
# Processing Record 48 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 13 | carmelo
# Processing Record 50 of Set 13 | tonantins
# Processing Record 1 of Set 14 | xai-xai
# Processing Record 2 of Set 14 | superior
# Processing Record 3 of Set 14 | moindou
# Processing Record 4 of Set 14 | aranos
# Processing Record 5 of Set 14 | sao joao da barra
# Processing Record 6 of Set 14 | pangnirtung
# Processing Record 7 of Set 14 | tamiahua
# Processing Record 8 of Set 14 | kemijarvi
# Processing Record 9 of Set 14 | cienaga
# Processing Record 10 of Set 14 | otradnoye
# Processing Record 11 of Set 14 | kabompo
# Processing Record 12 of Set 14 | yumen
# Processing Record 13 of Set 14 | thinadhoo
# Processing Record 14 of Set 14 | luwuk
# Processing Record 15 of Set 14 | dullewala
# Processing Record 16 of Set 14 | shimanovsk
# Processing Record 17 of Set 14 | ambulu
# Processing Record 18 of Set 14 | tessalit
# Processing Record 19 of Set 14 | mikkeli
# Processing Record 20 of Set 14 | canandaigua
# Processing Record 21 of Set 14 | erdenet
# Processing Record 22 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 14 | parabel
# Processing Record 24 of Set 14 | mana
# Processing Record 25 of Set 14 | muana
# Processing Record 26 of Set 14 | bilibino
# Processing Record 27 of Set 14 | guerrero negro
# Processing Record 28 of Set 14 | oussouye
# Processing Record 29 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 14 | jiayuguan
# Processing Record 31 of Set 14 | gamboula
# Processing Record 32 of Set 14 | hami
# Processing Record 33 of Set 14 | tilichiki
# Processing Record 34 of Set 14 | sandwick
# Processing Record 35 of Set 14 | kilindoni
# Processing Record 36 of Set 14 | ornskoldsvik
# Processing Record 37 of Set 14 | ihosy
# Processing Record 38 of Set 14 | zyryanka
# Processing Record 39 of Set 14 | morehead
# Processing Record 40 of Set 14 | banjarmasin
# Processing Record 41 of Set 14 | shingu
# Processing Record 42 of Set 14 | angoche
# Processing Record 43 of Set 14 | igunga
# Processing Record 44 of Set 14 | rio cuarto
# Processing Record 45 of Set 14 | lipari
# Processing Record 46 of Set 14 | sagar
# Processing Record 47 of Set 14 | betul
# Processing Record 48 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 14 | acajutla
# Processing Record 50 of Set 14 | lompoc
# Processing Record 1 of Set 15 | skibbereen
# Processing Record 2 of Set 15 | sorgun
# Processing Record 3 of Set 15 | jalu
# Processing Record 4 of Set 15 | akdepe
# Processing Record 5 of Set 15 | port hedland
# Processing Record 6 of Set 15 | ismailia
# Processing Record 7 of Set 15 | miquelon
# Processing Record 8 of Set 15 | ozernovskiy
# Processing Record 9 of Set 15 | kupino
# Processing Record 10 of Set 15 | mubarakpur
# Processing Record 11 of Set 15 | angoram
# Processing Record 12 of Set 15 | winnemucca
# Processing Record 13 of Set 15 | talara
# Processing Record 14 of Set 15 | lago da pedra
# Processing Record 15 of Set 15 | sao sepe
# Processing Record 16 of Set 15 | hovd
# Processing Record 17 of Set 15 | bossangoa
# Processing Record 18 of Set 15 | lasa
# Processing Record 19 of Set 15 | ponnani
# Processing Record 20 of Set 15 | karratha
# Processing Record 21 of Set 15 | jos
# Processing Record 22 of Set 15 | arona
# Processing Record 23 of Set 15 | pec
# Processing Record 24 of Set 15 | sao benedito do rio preto
# Processing Record 25 of Set 15 | alim
# Processing Record 26 of Set 15 | constitucion
# Processing Record 27 of Set 15 | boende
# Processing Record 28 of Set 15 | beruni
# City not found. Skipping...
# Processing Record 29 of Set 15 | nouakchott
# Processing Record 30 of Set 15 | spearfish
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(5)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint Anthony      US  45.0205  -93.2180      1.40        50          40
# 1       Ilhabela      BR -23.7781  -45.3581     77.47        64          39
# 2      Cape Town      ZA -33.9258   18.4232     72.00        78          40
# 3        Rikitea      PF -23.1203 -134.9692     77.85        73         100
# 4     Nikolskoye      RU  59.7035   30.7861     10.40        72          75
#
#    Wind Speed Current Description
# 0       16.11    scattered clouds
# 1        4.94    scattered clouds
# 2       11.50    scattered clouds
# 3       11.72          light rain
# 4       15.66                snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
